# %%
data = [
            {
              "name": "HAIR CARE 1",
              "image": {
                "name": "",
                "original": "https://i.ibb.co/McpqCrW/Whats-App-Image-2024-02-13-at-17-23-17-897a19e6.jpg",
                "thumb": ""
              }
            },
            {
              "name": "HAIR CARE 2",
              "image": {
                "name": "",
                "original": "https://i.ibb.co/McpqCrW/Whats-App-Image-2024-02-13-at-17-23-17-897a19e6.jpg",
                "thumb": ""
              }
            },
            {
              "quality": [
                "LowRes",
                "Shadow"
              ]
            },
            {
              "quality": [
                "LowRes",
                "Shadow"
              ]
            }
          ]

# %%
print(data)
# Out:
# [{'name': 'HAIR CARE 1', 'image': {'name': '', 'original': 'https://i.ibb.co/McpqCrW/Whats-App-Image-2024-02-13-at-17-23-17-897a19e6.jpg', 'thumb': ''}}, {'name': 'HAIR CARE 2', 'image': {'name': '', 'original': 'https://i.ibb.co/McpqCrW/Whats-App-Image-2024-02-13-at-17-23-17-897a19e6.jpg', 'thumb': ''}}, {'quality': ['LowRes', 'Shadow']}, {'quality': ['LowRes', 'Shadow']}]

# %%
new_data = {
                'GLOW & LOVELY BLMS BALM FOUNDATN CRM 40G': 'gl_foundation_crm',
                'GLOW & LOVELY FACIAL MOIST ARYUVEDIC 50G': 'gl_aryuvedic_crm',
                'GLOW & LOVELY FACIAL MST MLTVIT CRM 100G': 'gl_mltvit_crm',
                'GLOW & LOVELY FACIAL MST MLTVIT CRM 50G': 'gl_mltvit_crm',
                'PONDS FM CREAM COL MGT WHT BEAUTY 35G LC': 'ponds_white_beauty_crm',
                'PONDS FM CRM COLMGT WHT BEAUTY SPTLS 25G': 'ponds_white_beauty_crm',
                'GLOW & LOVELY FC WASH FM INSTA GLOW 100G': 'gl_insta_glow_fw',
                'PONDS FWL ESSTNL CARE WHITE BEAUTY 100G': 'ponds_white_beauty_fw',
                'PONDS FW LTN ESSNTL CARE PURE WHITE 100G': 'ponds_pure_white_fw',
                'PONDS FW OIL CNTRL 100G': 'ponds_oil_control_fw',
                'PONDS FWL CMGT PURE WHT CLAY FOAM 90G': 'ponds_pure_white_clay_fw',
                'PONDS FWL CMGT WHT BEAUTY CLAY FOAM 90G': 'ponds_white_beauty_clay_fw',
                'SUNSILK SHAMPOO BLACK 450ML': 'sunsilk_black_large',
                'SUNSILK SHAMPOO BLACK 375ML': 'sunsilk_black_small',
                'SUNSILK SHAMPOO BLACK 180ML': 'sunsilk_black_small',
                'SUNSILK SHAMPOO THICK & LONG 450ML': 'sunsilk_tl_large',
                'SUNSILK SHAMPOO THICK & LONG 375ML': 'sunsilk_tl_small',
                'SUNSILK SHAMPOO THICK & LONG 180ML': 'sunsilk_tl_small',
                'SUNSILK SHAMPOO HIJAB RCHRG REFRSH 375ML': 'sunsilk_hrr',
                'SUNSILK SHMP HIJAB RECHRGE REFRESH 180ML': 'sunsilk_hrr',
                'SUNSILK SHAMPOO VOLUME 375ML': 'sunsilk_volume',
                'SUNSILK SHAMPOO VOLUME 195ML': 'sunsilk_volume',
                'SUNSILK SHAMPOO FRESHNESS 375ML': 'sunsilk_fresh',
                'SUNSILK SHAMPOO FRESHNESS 195ML': 'sunsilk_fresh',
                'CLEAR SHAMPOO ANTI HAIR FALL 350ML': 'clear_ahf',
                'CLEAR SHAMPOO ANTI HAIR FALL 180ML': 'clear_ahf',
                'CLEAR SHAMPOO COMPLETE ACTVE CARE 350ML': 'clear_cac',
                'CLEAR SHAMPOO COMPLETE ACTVE CARE 180ML': 'clear_cac',
                'CLEAR MALE SHAMPOO CSM 450ML': 'clear_csm_large',
                'CLEAR MALE SHAMPOO CSM 330ML': 'clear_csm_small',
                'CLEAR MALE SHAMPOO CSM 180ML': 'clear_csm_small',
                'TRESEMME SHAMPOO COLOR REVITALISE 580ML': 'tresemme_cr',
                'TRESEMME SHAMPOO KERATIN SMOOTH 580ML': 'tresemme_ks_large',
                'TRESEMME SHAMPOO KERATIN SMOOTH 340ML': 'tresemme_ks_small',
                'DOVE SHAMPOO HAIR FALL RESCUE 650ML': 'dove_hfr_large',
                'DOVE SHAMPOO HAIR FALL RESCUE 340ML': 'dove_hfr_small',
                'DOVE SHAMPOO HAIR FALL RESCUE 170ML': 'dove_hfr_small',
                'DOVE SHAMPOO IRP 650ML': 'dove_irp_large',
                'DOVE SHAMPOO INTENSIVE REPAIR 340ML': 'dove_irp_small',
                'DOVE SHAMPOO INTENSIVE REPAIR 170ML': 'dove_irp_small',
                'DOVE HEALTHY GROWTH 340ML': 'dove_hg',
                'DOVE SHAMPOO NOURISHING OIL 340ML': 'dove_no',
                'DOVE HAIR RINSE OUT CONDITIONR HFR 180ML': 'dove_cond',
                'DOVE REG RINSE OUT CNDTNR IRP 175ML': 'dove_cond',
                'SUNSILK SHAMPOO HFS 375ML': 'sunsilk_hfs',
                'SUNSILK SHAMPOO HFS 180ML': 'sunsilk_hfs',
                'HORLICKS HFD STD JAR 1000G': 'horlicks_std',
                'HORLICKS HFD STD JAR 500G': 'horlicks_std',
                'HORLICKS HFD JUNIOR STAGE-2 JAR 500G': 'horlicks_junior',
                'HORLICKS HFD CHOCOLATE JAR 500G': 'horlicks_choco',
                'HORLICKS HFD WOMEN JAR 400G': 'horlicks_women',
                'HORLICKS HFD MOTHER BIB 350G': 'horlicks_mother',
                'HORLICKS HFD LITE JAR 330G': 'horlicks_lite',
                'MALTOVA HFD STANDARD BIB 400G': 'maltova_std',
                'BOOST HFD STANDARD JAR 400G': 'boost_std',
                'PEPSODENT SEN PROFESSIONAL': 'PEPSODENT',
                'PEPSODENT ADV SEN FRESH': 'PEPSODENT',
                'PEPSODENT SEN GUM CARE': 'PEPSODENT',
                'VASELINE TM 200ML': 'vaseline_tm',
                'Vaseline Deep Restore hh': 'vaseline_tm',
                'Vaseline Deep Restore Lotion': 'vaseline_tm',
                'Vaseline Daily Brightening Lotion': 'vaseline_hw',
                'VASELINE HW 200ML': 'vaseline_hw',
                'Vaseline Aloe Fresh Lotion': 'vaseline_aloe',
                'VASELINE ALOE 200ML': 'vaseline_aloe',
                'Dove Nourishing Body Care Lotion': 'dove_qpds',
                'DOVE 250ML': 'dove_qpds',
                'GAL BLM BBF CRM 40ML': 'gl_foundation_crm',
                'GAL AV CRM 50ML': 'gl_aryuvedic_crm',
                'GAL MV CRM 100ML /50ML/25ML': 'gl_mltvit_crm',
                'PONDS WB CRM 35ML/ 25ML': 'ponds_white_beauty_crm',
                'GAL FW 100ML': 'gl_insta_glow_fw',
                'PONDS WB FW 100ML': 'ponds_white_beauty_fw',
                'PONDS PURE WHT FW 100ML': 'ponds_pure_white_fw',
                'PONDS FW OIL CNTRL 100ML': 'ponds_oil_control_fw',
                'SS SHMP BLACK 450ML': 'sunsilk_black_large',
                'SS SHMP BLACK 375ML/180ML': 'sunsilk_black_small',
                'SS SHMP T&L 450ML': 'sunsilk_tl_large',
                'SS SHMP T&L 375ML/180ML': 'sunsilk_tl_small',
                'SS SHMP VOLUME 375ML/195ML': 'sunsilk_volume',
                'CLEAR SHMP AHF 375ML/180ML': 'clear_ahf',
                'CLEAR SHMP CAC 350ML/180ML': 'clear_cac',
                'CLEAR MALE SHMP CSM 450ML': 'clear_csm_large',
                'CLEAR MALE SHMP CSM 330ML/180ML': 'clear_csm_small',
                'TRESEMME SHMP CR 580ML': 'tresemme_cr',
                'TRESEMME SHMP KS 580ML': 'tresemme_ks_large',
                'TRESEMME SHMP KS 340ML': 'tresemme_ks_small',
                'DOVE SHMP HFR 650ML': 'dove_hfr_large',
                'DOVE SHMP HFR 340ML/170ML': 'dove_hfr_small',
                'DOVE SHMP IRP 650ML': 'dove_irp_large',
                'DOVE SHMP IRP 340ML/170ML': 'dove_irp_small',
                'DOVE SHMP NR OIL 340ML': 'dove_no',
                'DOVE COND 180ML/175ML': 'dove_cond',
                'SS SHMP HFS 375ML/180ML': 'sunsilk_hfs',
                'HORLICKS STD JAR 1000G/500G': 'horlicks_std',
                'HORLICKS JR STG JAR 500G': 'horlicks_junior', # merge stage 1 and stage 2
                'HORLICKS CHOC JAR 500G': 'horlicks_choco',
                'HORLICKS WOMEN JAR 400G': 'horlicks_women',
                'HORLICKS MOTHER BIB 350G': 'horlicks_mother',
                'HORLICKS LITE JAR 330G': 'horlicks_lite',
                'MALTOVA STANDARD BIB 400G': 'maltova_std',
                'BOOST STD JAR 400G': 'boost_std',
                'TRESEMME COND KS LC 190ML': 'tresemme_ks_white', # new add v1
                'DOVE SMP OXG MT 340ML': 'dove_oxg', # new add v1
                'SUNSILK SMP ON 375ML': 'sunsilk_onion', # new add v1
                }

# %%
a = []
for value in new_data.values():
    if value not in a:
        a.append(value)

# %%
print(a)
# Out:
# ['gl_foundation_crm', 'gl_aryuvedic_crm', 'gl_mltvit_crm', 'ponds_white_beauty_crm', 'gl_insta_glow_fw', 'ponds_white_beauty_fw', 'ponds_pure_white_fw', 'ponds_oil_control_fw', 'ponds_pure_white_clay_fw', 'ponds_white_beauty_clay_fw', 'sunsilk_black_large', 'sunsilk_black_small', 'sunsilk_tl_large', 'sunsilk_tl_small', 'sunsilk_hrr', 'sunsilk_volume', 'sunsilk_fresh', 'clear_ahf', 'clear_cac', 'clear_csm_large', 'clear_csm_small', 'tresemme_cr', 'tresemme_ks_large', 'tresemme_ks_small', 'dove_hfr_large', 'dove_hfr_small', 'dove_irp_large', 'dove_irp_small', 'dove_hg', 'dove_no', 'dove_cond', 'sunsilk_hfs', 'horlicks_std', 'horlicks_junior', 'horlicks_choco', 'horlicks_women', 'horlicks_mother', 'horlicks_lite', 'maltova_std', 'boost_std', 'PEPSODENT', 'vaseline_tm', 'vaseline_hw', 'vaseline_aloe', 'dove_qpds', 'tresemme_ks_white', 'dove_oxg', 'sunsilk_onion']

# %%
[
'gl_foundation_crm',
'gl_aryuvedic_crm',
'gl_mltvit_crm',
'ponds_white_beauty_crm',
'gl_insta_glow_fw',
'ponds_white_beauty_fw',
'ponds_pure_white_fw',
'ponds_oil_control_fw',
'ponds_pure_white_clay_fw',
'ponds_white_beauty_clay_fw',
'sunsilk_black_large',
'sunsilk_black_small',
'sunsilk_tl_large',
'sunsilk_tl_small',
'sunsilk_hrr',
'sunsilk_volume',
'sunsilk_fresh',
'clear_ahf',
'clear_cac',
'clear_csm_large',
'clear_csm_small',
'tresemme_cr',
'tresemme_ks_large',
'tresemme_ks_small',
'dove_hfr_large',
'dove_hfr_small',
'dove_irp_large',
'dove_irp_small',
'dove_hg',
'dove_no',
'dove_cond',
'sunsilk_hfs',
'horlicks_std',
'horlicks_junior',
'horlicks_choco',
'horlicks_women',
'horlicks_mother',
'horlicks_lite',
'maltova_std',
'boost_std',
'PEPSODENT',
'vaseline_tm',
'vaseline_hw',
'vaseline_aloe',
'dove_qpds',
'tresemme_ks_white',
'dove_oxg',
'sunsilk_onion'
]

# %%
a = {
                        'clear_cac':'CLEAR SHAMPOO COMPLETE ACTIVE CARE 350ML/180ML',
                        'ponds_white_beauty_clay_fw': 'PONDS FW COL MGT WHT BEAUTY 100G/50G',
                        'lux_aloe': 'LUX SHW BW FREEASIA SCNT&ALOE VERA',
                        'clear_ahf': 'CLEAR SHAMPOO ANTI HAIR FALL 350ML/180ML',
                        'horlicks_jr_bib_2': 'HORLICKS FUNC NTR JUNIOR STAGE-2 BIB 500G',
                        'dove_cond': 'DOVE HAIR RINSE OUT CONDTNR HFR/IRP LC 170ML',
                        'dove_irp_large': 'DOVE SHAMPOO IRP 650ML/480ML/450ML',
                        'sunsilk_black_large': 'SUNSILK SHAMPOO BLACK 450ML',
                        'sunsilk_perfect': 'SUNSILK SHAMPOO PERFECT STRAIGHT 375ML',
                        'horlicks_women': 'HORLICKS FUNC NTR WOMEN JAR 400G',
                        'gl_men_fw': 'GLOW & HANDSOME MEN FACE WASH 100G/50G',
                        'gl_foundation_crm': 'GLOW & LOVELY BLMS BALM FOUNDATN CRM 40G/18G',
                        'glucomax_d': 'GLUCOMAX D FUNC NTR STD BIB 400G/200G',
                        'lb_red_gallon_5l': 'LIFEBUOY LIQUID HAND SOAP TOTAL 5L',
                        'knorr_hot_sour': 'KNORR INSTANT SOUP HOT & SOUR 31G',
                        'tresemme_hd': 'TRESEMME SHAMPOO HAIR FALL DEFENSE 580ML',
                        'ponds_oil_control_fw': 'PONDS FW OIL CNTRL 100G',
                        'tresemme_ks_wt': 'TRESEMME RRO COND KERATN SMOOTH LC 190ML',
                        'tresemme_ks_large': 'TRESEMME SHAMPOO KERATIN SMOOTH 580ML',
                        'LIFEBUOY': "LIFEBUOY SKIN CLEANSING BAR",
                        'ponds_cold_crm': 'PONDS FM ESSNTL CARE COLD CREAM 50G/28G',
                        'pepsodent_pwdr': 'PEPSODENT TOOTH POWDER 100G',
                        'vaseline_aloe': 'VASELINE BODY LOTION ALOE SOOTHE 200ML',
                        'lux_orchd': 'LUX SHW BW BLK ORCHD SCNT&JNPR OIL',
                        'rin_pwdr': 'RIN NM STD POWDER POWER WHITE 2KG/1000G/500G',
                        'surfxl_lqd': 'SURF EXCEL MATC STD LQD TOP LOAD 1020ML/500ML',
                        'vaseline_petro_aloe': 'VASELINE BODY PETROLEUM JELLY ALOE 50ML',
                        'vim_gallon': 'VIM HDW STD LIQUID 1L',
                        'dove_hfr_small': 'DOVE SHAMPOO HAIR FALL RESCUE 340ML/170ML',
                        'ponds_pure_white_clay_fw': 'PONDS FW COL MGT PURE WHT 100G/90G',
                        'tresemme_ks_small': 'TRESEMME SHAMPOO KERATIN SMOOTH 340ML/185ML',
                        'gl_wntr_crm': 'GLOW & LOVELY FM WINTER CREAM 50G/25G',
                        'horlicks_lite': 'HORLICKS FUNC NTR LITE JAR 330G',
                        'wheel_soap': 'WHEEL HARD SOAP 130G',
                        'boost_std': 'BOOST FUNC NTR STANDARD JAR 400G',
                        'sunsilk_black_small': 'SUNSILK SHAMPOO BLACK 375ML/180ML',
                        'ponds_super_lgt': 'PONDS SUPER LIGHT GEL 98G/49G',
                        'vaseline_tm': 'VASELINE LOTION TOT MOIST 400ML/300ML/200ML/100ML/50ML',
                        'lux_almond': 'LUX SHW BW FRENCH ROSE&ALMOND OIL',
                        'vaseline_hw': 'VASELINE LOTION HEALTHY WHITE 400ML/300ML/200ML/100ML',
                        'sunsilk_volume': 'SUNSILK SHAMPOO VOLUME 375ML/195ML',
                        'gl_men_crm': 'GLOW & HANDSOME MEN FCE MSTRSR CREAM 50G/25G',
                        'knorr_corn': 'KNORR INSTANT SOUP CHICKEN CORN 24G',
                        'pepsodent': "PEPSODENT TOOTHPASTE GERMICHECK 200G/140G/100G/40G",
                        'wheel_pwdr': 'WHEEL NM STD PWDR CLEAN&FRESH 2KG/1000G/500G',
                        'lux_soft': 'LUX SKIN CLEANSING BAR SOFT TOUCH',
                        'lb_red_handwash': 'LIFEBUOY LIQUID HAND SOAP TOTAL 200ML',
                        'ponds_lgt_oil_fw': 'PONDS MEN FW FOAM LIGHT OIL 100G/50G',
                        'horlicks_junior': 'HORLICKS FUNC NTR JUNIOR STAGE-2 JAR 500G',
                        'vaseline_mosq': 'VASELINE BDY LOTN MOSQUITO DEFENCE 100ML/50ML',
                        'maltova_std': 'MALTOVA FUNC NTR STANDARD BIB 400G',
                        'horlicks_std': 'HORLICKS FUNC NTR STD JAR 1000G/500G/250G',
                        'sunsilk_tl_large': 'SUNSILK SHAMPOO THICK & LONG 650ML/450ML',
                        'lb_lmn_packet': 'LIFEBUOY LIQUID HAND SOAP LMN FRSH 200ML',
                        'gl_mltvit_crm': 'GLOW & LOVELY FACIAL MST MLTVIT CRM 100G/80G/50G/25G',
                        'lb_red_packet': 'LIFEBUOY LIQUID HAND SOAP TOTAL 180ML',
                        'domex_lime': 'DOMEX STD LQD TLT CLNRS LIME FRESH 750ML/500ML',
                        'sunsilk_hfs': 'SUNSILK SHAMPOO HFS 375ML/180ML',
                        'sunsilk_fresh': 'SUNSILK SHAMPOO FRESHNESS 375ML/195ML',
                        'domex_ocen': 'DOMEX STD LQD TLT CLNRS OCEN FRESH 750ML/500ML',
                        'ponds_moist_body': 'PONDS LOTION MOISTURIZING BODY 200ML',
                        'vaseline_ln_white_lc': 'VASELINE LOTION HEALTHY WHITE LC 400ML',
                        'ponds_oil_cntr_fw': 'PONDS MEN FW FOAM OIL CONTROL 100G/50G',
                        'gl_aryuvedic_crm': 'GLOW & LOVELY FACIAL MOIST ARYUVEDIC 50G/25G',
                        'ponds_pure_white_fw': 'PONDS FW FOAM PURE WHITE 100G/50G',
                        'dove_pink': 'DOVE BAR PINK 100G',
                        'dove_no': 'DOVE SHAMPOO NOURISHING OIL 340ML/170ML',
                        'clear_csm_small': 'CLEAR MALE SHAMPOO CSM 330ML/180ML',
                        'knorr_frd_chicken': 'KNORR OTH CKG INGRD FRIED CHICKN MIX 75G',
                        'clinic_strong': 'CLINIC PLUS SHMP STRNG&LONG HEALTH 340ML',
                        'sunsilk_tl_small': 'SUNSILK SHAMPOO THICK & LONG 375ML/180ML',
                        'horlicks_jr_jar_1': 'HORLICKS FUNC NTR JUNIOR STAGE-1 JAR 500G',
                        'knorr_thai': 'KNORR INSTANT SOUP CLASSIC THAI 28G',
                        'dove_hg': 'DOVE SHAMPOO HEALTHY GROWTH 340ML/170ML',
                        'tresemme_cr': 'TRESEMME SHAMPOO COLOR REVITALISE 580ML',
                        'vaseline_total_moist': 'VASELINE LOTION TOTAL MOIST LC 400ML',
                        'vaseline_petro': 'VASELINE PETROLEUM JELLY 50ML/9ML',
                        'PONDS': 'PONDS FW ESS CARE DAILY 100G/50G',
                        'sunsilk_hrr': 'SUNSILK SHAMPOO HIJAB RCHRG REFRSH 375ML',
                        'lb_blue_handwash': 'LIFEBUOY LIQUID HAND SOAP CARE 200ML',
                        'horlicks_mother': 'HORLICKS FUNC NTR MOTHER BIB 350G',
                        'vim_bar': 'VIM HDW NSD BAR 300G/100G',
                        'horlicks_pouch': 'HORLICKS FUNC NTR STD POUCH 500G',
                        'dove_oxy': 'DOVE SHAMPOO OXYGEN MOISTURE 340ML',
                        'lb_lmn_handwash': 'LIFEBUOY LIQUID HAND SOAP LMN FRSH 180ML',
                        'clear_csm_large': 'CLEAR MALE SHAMPOO CSM 450ML',
                        'rin_lqd': 'RIN NM STD LIQUID 800ML/400ML',
                        'LUX': 'LUX SKIN CLEANSING BAR 150G/125G/75G',
                        'vaseline_petro_cocoa': 'VASELINE BODY PETROLEUM JELLY COCOA 50ML',
                        'ponds_white_beauty_fw': 'PONDS FW BRIGHT BEAUTY 50G',
                        'dove_white': 'DOVE PW BAR 135G/100G',
                        'lb_lmn_bottle_1l': 'LIFEBUOY LIQUID HAND SOAP LEMON FRESH 1L',
                        'surfxl_pwdr': 'SURF NM STD POWDER EXCEL 1000G/500G',
                        'lb_blue_packet': 'LIFEBUOY LIQUID HAND SOAP CARE 180ML',
                        'dove_hfr_large': 'DOVE SHAMPOO HAIR FALL RESCUE 650ML/480ML',
                        'ponds_white_beauty_crm': 'PONDS CREAM COL MGT WHT BEAUTY 50G/35G',
                        'vim_bottle': 'VIM HDW STD LIQUID 500ML',
                        'dove_hijab': 'DOVE SHAMPOO HIJAB 340ML',
                        'CLOSE UP': 'CLOSE-UP THPSTE FRESHNSS MINT CHILL 145G/100G',
                        'horlicks_choco': 'HORLICKS FUNC NTR CHOCOLATE JAR 500G',
                        'vim_packet': 'VIM HDW STD LIQUID 250ML',
                        'vim_pwdr': 'VIM HDW ABR POWDER 500G',
                        'ponds_van_crm': 'PONDS CREAM OIL CNTRL VAN CRM 50G/30G/28G',
                        'ponds_antibac': 'PONDS FWL ESSTNL CARE ANTIBAC 100G',
                        'tresemme_nr': 'TRESEMME SHAMPOO NOURISH REPLENISH 580ML',
                        'gl_insta_glow_fw': 'GLOW & LOVELY FC WSH FOAM INSTA GLOW 100G/50G',
                        'dove_irp_small': 'DOVE SHAMPOO IRP 340ML/330ML/196ML/170ML/80ML',
                        'lb_red_bottle_1l': 'LIFEBUOY LIQUID HAND SOAP TOTAL 1L'
                    }

# %%
new_data = {
                "CLEAR SHAMPOO COMPLETE ACTIVE CARE 350ML/180ML" : "10 inch",
                "PONDS FW COL MGT WHT BEAUTY 100G/50G" : "10 inch",
                "LUX SHW BW FREEASIA SCNT&ALOE VERA" : "10 inch",
                "CLEAR SHAMPOO ANTI HAIR FALL 350ML/180ML" : "10 inch",
                "HORLICKS FUNC NTR JUNIOR STAGE-2 BIB 500G" : "10 inch",
                "DOVE HAIR RINSE OUT CONDTNR HFR/IRP LC 170ML" : "10 inch",
                "DOVE SHAMPOO IRP 650ML/480ML/450ML" : "10 inch",
                "SUNSILK SHAMPOO BLACK 450ML" : "10 inch",
                "SUNSILK SHAMPOO PERFECT STRAIGHT 375ML" : "10 inch",
                "HORLICKS FUNC NTR WOMEN JAR 400G" : "10 inch",
                "GLOW & HANDSOME MEN FACE WASH 100G/50G" : "10 inch",
                "GLOW & LOVELY BLMS BALM FOUNDATN CRM 40G/18G" : "10 inch",
                "GLUCOMAX D FUNC NTR STD BIB 400G/200G" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP TOTAL 5L" : "10 inch",
                "KNORR INSTANT SOUP HOT & SOUR 31G" : "10 inch",
                "TRESEMME SHAMPOO HAIR FALL DEFENSE 580ML" : "10 inch",
                "PONDS FW OIL CNTRL 100G" : "10 inch",
                "TRESEMME RRO COND KERATN SMOOTH LC 190ML" : "10 inch",
                "TRESEMME SHAMPOO KERATIN SMOOTH 580ML" : "10 inch",
                "LIFEBUOY SKIN CLEANSING BAR" : "10 inch",
                "PONDS FM ESSNTL CARE COLD CREAM 50G/28G" : "10 inch",
                "PEPSODENT TOOTH POWDER 100G" : "10 inch",
                "VASELINE BODY LOTION ALOE SOOTHE 200ML" : "10 inch",
                "LUX SHW BW BLK ORCHD SCNT&JNPR OIL" : "10 inch",
                "RIN NM STD POWDER POWER WHITE 2KG/1000G/500G" : "10 inch",
                "SURF EXCEL MATC STD LQD TOP LOAD 1020ML/500ML" : "10 inch",
                "VASELINE BODY PETROLEUM JELLY ALOE 50ML" : "10 inch",
                "VIM HDW STD LIQUID 1L" : "10 inch",
                "DOVE SHAMPOO HAIR FALL RESCUE 340ML/170ML" : "10 inch",
                "PONDS FW COL MGT PURE WHT 100G/90G" : "10 inch",
                "TRESEMME SHAMPOO KERATIN SMOOTH 340ML/185ML" : "10 inch",
                "GLOW & LOVELY FM WINTER CREAM 50G/25G" : "10 inch",
                "HORLICKS FUNC NTR LITE JAR 330G" : "10 inch",
                "WHEEL HARD SOAP 130G" : "10 inch",
                "BOOST FUNC NTR STANDARD JAR 400G" : "10 inch",
                "SUNSILK SHAMPOO BLACK 375ML/180ML" : "10 inch",
                "PONDS SUPER LIGHT GEL 98G/49G" : "10 inch",
                "VASELINE LOTION TOT MOIST 400ML/300ML/200ML/100ML/50ML" : "10 inch",
                "LUX SHW BW FRENCH ROSE&ALMOND OIL" : "10 inch",
                "VASELINE LOTION HEALTHY WHITE 400ML/300ML/200ML/100ML" : "10 inch",
                "SUNSILK SHAMPOO VOLUME 375ML/195ML" : "10 inch",
                "GLOW & HANDSOME MEN FCE MSTRSR CREAM 50G/25G" : "10 inch",
                "KNORR INSTANT SOUP CHICKEN CORN 24G" : "10 inch",
                "PEPSODENT TOOTHPASTE GERMICHECK 200G/140G/100G/40G" : "10 inch",
                "WHEEL NM STD PWDR CLEAN&FRESH 2KG/1000G/500G" : "10 inch",
                "LUX SKIN CLEANSING BAR SOFT TOUCH" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP TOTAL 200ML" : "10 inch",
                "PONDS MEN FW FOAM LIGHT OIL 100G/50G" : "10 inch",
                "HORLICKS FUNC NTR JUNIOR STAGE-2 JAR 500G" : "10 inch",
                "VASELINE BDY LOTN MOSQUITO DEFENCE 100ML/50ML" : "10 inch",
                "MALTOVA FUNC NTR STANDARD BIB 400G" : "10 inch",
                "HORLICKS FUNC NTR STD JAR 1000G/500G/250G" : "10 inch",
                "SUNSILK SHAMPOO THICK & LONG 650ML/450ML" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP LMN FRSH 200ML" : "10 inch",
                "GLOW & LOVELY FACIAL MST MLTVIT CRM 100G/80G/50G/25G" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP TOTAL 180ML" : "10 inch",
                "DOMEX STD LQD TLT CLNRS LIME FRESH 750ML/500ML" : "10 inch",
                "SUNSILK SHAMPOO HFS 375ML/180ML" : "10 inch",
                "SUNSILK SHAMPOO FRESHNESS 375ML/195ML" : "10 inch",
                "DOMEX STD LQD TLT CLNRS OCEN FRESH 750ML/500ML" : "10 inch",
                "PONDS LOTION MOISTURIZING BODY 200ML" : "10 inch",
                "VASELINE LOTION HEALTHY WHITE LC 400ML" : "10 inch",
                "PONDS MEN FW FOAM OIL CONTROL 100G/50G" : "10 inch",
                "GLOW & LOVELY FACIAL MOIST ARYUVEDIC 50G/25G" : "10 inch",
                "PONDS FW FOAM PURE WHITE 100G/50G" : "10 inch",
                "DOVE BAR PINK 100G" : "10 inch",
                "DOVE SHAMPOO NOURISHING OIL 340ML/170ML" : "10 inch",
                "CLEAR MALE SHAMPOO CSM 330ML/180ML" : "10 inch",
                "KNORR OTH CKG INGRD FRIED CHICKN MIX 75G" : "10 inch",
                "CLINIC PLUS SHMP STRNG&LONG HEALTH 340ML" : "10 inch",
                "SUNSILK SHAMPOO THICK & LONG 375ML/180ML" : "10 inch",
                "HORLICKS FUNC NTR JUNIOR STAGE-1 JAR 500G" : "10 inch",
                "KNORR INSTANT SOUP CLASSIC THAI 28G" : "10 inch",
                "DOVE SHAMPOO HEALTHY GROWTH 340ML/170ML" : "10 inch",
                "TRESEMME SHAMPOO COLOR REVITALISE 580ML" : "10 inch",
                "VASELINE LOTION TOTAL MOIST LC 400ML" : "10 inch",
                "VASELINE PETROLEUM JELLY 50ML/9ML" : "10 inch",
                "PONDS FW ESS CARE DAILY 100G/50G" : "10 inch",
                "SUNSILK SHAMPOO HIJAB RCHRG REFRSH 375ML" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP CARE 200ML" : "10 inch",
                "HORLICKS FUNC NTR MOTHER BIB 350G" : "10 inch",
                "VIM HDW NSD BAR 300G/100G" : "10 inch",
                "HORLICKS FUNC NTR STD POUCH 500G" : "10 inch",
                "DOVE SHAMPOO OXYGEN MOISTURE 340ML" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP LMN FRSH 180ML" : "10 inch",
                "CLEAR MALE SHAMPOO CSM 450ML" : "10 inch",
                "RIN NM STD LIQUID 800ML/400ML" : "10 inch",
                "LUX SKIN CLEANSING BAR 150G/125G/75G" : "10 inch",
                "VASELINE BODY PETROLEUM JELLY COCOA 50ML" : "10 inch",
                "PONDS FW BRIGHT BEAUTY 50G" : "10 inch",
                "DOVE PW BAR 135G/100G" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP LEMON FRESH 1L" : "10 inch",
                "SURF NM STD POWDER EXCEL 1000G/500G" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP CARE 180ML" : "10 inch",
                "DOVE SHAMPOO HAIR FALL RESCUE 650ML/480ML" : "10 inch",
                "PONDS CREAM COL MGT WHT BEAUTY 50G/35G" : "10 inch",
                "VIM HDW STD LIQUID 500ML" : "10 inch",
                "DOVE SHAMPOO HIJAB 340ML" : "10 inch",
                "CLOSE-UP THPSTE FRESHNSS MINT CHILL 145G/100G" : "10 inch",
                "HORLICKS FUNC NTR CHOCOLATE JAR 500G" : "10 inch",
                "VIM HDW STD LIQUID 250ML" : "10 inch",
                "VIM HDW ABR POWDER 500G" : "10 inch",
                "PONDS CREAM OIL CNTRL VAN CRM 50G/30G/28G" : "10 inch",
                "PONDS FWL ESSTNL CARE ANTIBAC 100G" : "10 inch",
                "TRESEMME SHAMPOO NOURISH REPLENISH 580ML" : "10 inch",
                "GLOW & LOVELY FC WSH FOAM INSTA GLOW 100G/50G" : "10 inch",
                "DOVE SHAMPOO IRP 340ML/330ML/196ML/170ML/80ML" : "10 inch",
                "LIFEBUOY LIQUID HAND SOAP TOTAL 1L" : "10 inch",
                }
# Out:
# CLEAR SHAMPOO COMPLETE ACTIVE CARE 350ML/180ML
# PONDS FW COL MGT WHT BEAUTY 100G/50G
# LUX SHW BW FREEASIA SCNT&ALOE VERA
# CLEAR SHAMPOO ANTI HAIR FALL 350ML/180ML
# HORLICKS FUNC NTR JUNIOR STAGE-2 BIB 500G
# DOVE HAIR RINSE OUT CONDTNR HFR/IRP LC 170ML
# DOVE SHAMPOO IRP 650ML/480ML/450ML
# SUNSILK SHAMPOO BLACK 450ML
# SUNSILK SHAMPOO PERFECT STRAIGHT 375ML
# HORLICKS FUNC NTR WOMEN JAR 400G
# GLOW & HANDSOME MEN FACE WASH 100G/50G
# GLOW & LOVELY BLMS BALM FOUNDATN CRM 40G/18G
# GLUCOMAX D FUNC NTR STD BIB 400G/200G
# LIFEBUOY LIQUID HAND SOAP TOTAL 5L
# KNORR INSTANT SOUP HOT & SOUR 31G
# TRESEMME SHAMPOO HAIR FALL DEFENSE 580ML
# PONDS FW OIL CNTRL 100G
# TRESEMME RRO COND KERATN SMOOTH LC 190ML
# TRESEMME SHAMPOO KERATIN SMOOTH 580ML
# LIFEBUOY SKIN CLEANSING BAR
# PONDS FM ESSNTL CARE COLD CREAM 50G/28G
# PEPSODENT TOOTH POWDER 100G
# VASELINE BODY LOTION ALOE SOOTHE 200ML
# LUX SHW BW BLK ORCHD SCNT&JNPR OIL
# RIN NM STD POWDER POWER WHITE 2KG/1000G/500G
# ...
